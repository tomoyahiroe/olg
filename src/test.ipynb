# %%
import pickle
import numpy as np
import os
import re
import matplotlib.pyplot as plt
import olg


# その他のmatplotlib設定
plt.rcParams["figure.figsize"] = (14, 10)
plt.rcParams["font.size"] = 11
plt.rcParams["axes.unicode_minus"] = False  # マイナス記号の文字化け防止

# %%
# 結果ファイルを読み込み
with open("results/psi_50to25_by5T/value_functions.pkl", "rb") as f:
    value_functions = pickle.load(f)

# %%
redefined_initial_setting = olg.ss.setting.Setting(Na = 101)
initial_result = olg.ss.solve_ss(redefined_initial_setting)
# Out:
# Iteration 1: market_diff = 6.790336e-01, errm = 0.000000e+00
# Iteration 2: market_diff = 1.282027e-01, errm = 0.000000e+00
# Iteration 3: market_diff = 2.525755e-02, errm = 0.000000e+00
# Iteration 4: market_diff = 4.500368e-03, errm = 0.000000e+00
# Iteration 5: market_diff = 9.012628e-04, errm = 0.000000e+00
# \n計算完了! 実行時間: 8.80秒
# 総イテレーション数: 5
# 最終市場差: 9.012628e-04
# 最終人口合計誤差: 0.000000e+00
# 収束した資本ストック K = 6.1676

# %%
value_functions.shape
# Out:
# (5, 61, 2, 101)
